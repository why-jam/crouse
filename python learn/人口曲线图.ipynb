# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.style.use("_classic_test")

fig = plt.figure()
axes=fig.gca()
rng = np.random.RandomState(0)
a = rng.randn(100)
b = rng.randn(100)
colors = rng.rand(100)
sizes = 100*rng.rand(100)
plt.scatter(a,b,c=colors,s=sizes,alpha = 0.3)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"C:\\WINDOWS\\Fonts\\simsun.ttc", size=14) #导入中文字符

plt.style.use("_classic_test")
fig = plt.figure(figsize=(10,6),dpi=100)
axes=fig.gca()

#axes.set_xlim(2010,2018)
#axes.set_ylim(1200,2800)
axes.set_xlabel('年份',fontproperties=font)
axes.set_ylabel('人口(万人)',fontproperties=font)
axes.set_title('人口',fontproperties=font)
x = ['2010','2011','2012','2013','2014','2015','2016','2017','2018']
y1 = [2154,2171,2173,2171,2152,2115,2069,2019,1962]#北京
y2 = [1560,1557,1562,1547,1517,1472,1413,1355,1299]#天津
y3 = [2534,2529,2520,2511,2505,2498,2490,2482,2472]#吉林
#北京
ln1=axes.plot(x,y1,'r',linewidth = 2.0,linestyle='--')#linewidth 表示线宽
for a,b in zip(x,y1):
    axes.text(a,b,(a,b),ha = 'center',va = 'bottom',fontsize =9)

#天津
ln2=plt.plot(x,y2,'g',linewidth = 3.0,linestyle = '-.')
for a,b in zip(x,y2):
    axes.text(a,b,(a,b),fontsize =9) #fonsize 表示折线上数字间距离

#吉林
ln3=plt.plot(x,y3,'y',linewidth = 2.0)
for a,b in zip(x,y3):
    axes.text(a,b,(a,b))

#import matplotlib.font_manager as fm
#my_font=fm.FontProperties(fname="C:\Windows\Fonts\simkai.ttf")
#图例标识
plt.legend(labels=['北京市','天津市','吉林省'],
           loc='lower right', prop=font)#这里prop不能和上面fontproperties交换

plt.show()

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"C:\\WINDOWS\\Fonts\\simsun.ttc", size=14)

# %%
y1 = [np.random.randint(0,10) for i in range(10)]
y1
# Out:
# [8, 3, 4, 0, 7, 6, 5, 8, 4, 7]

# %%
np.random.randint(1,10,10)
# Out:
# array([4, 7, 5, 4, 4, 7, 9, 1, 4, 9])

# %%
y1
# Out:
# array([2154, 2171, 2173, 2171, 2152, 2115, 2069, 2019, 2962])

# %%
(x1,y1)
# Out:
# (array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]),
#  array([2154, 2171, 2173, 2171, 2152, 2115, 2069, 2019, 2962]))
